# %%
from PIL import Image

# %%
img = Image.open('img.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x1DA02D2B688>

# %%
import numpy as np

# %%
z = img.convert('RGB')

# %%
x = np.array(img)

# %%
np.array(z).shape
# Out:
# (1080, 1920, 3)

# %%
x.shape
# Out:
# (1080, 1920, 4)

# %%
jpg = Image.open('img.jpg')

# %%
jpg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1296x728 at 0x1DA05ADD908>

# %%
import numpy as np

# %%
z = jpg.convert('RGB')

# %%
x = np.array(img)

# %%
np.array(z).shape
# Out:
# (728, 1296, 3)
